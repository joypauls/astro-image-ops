# %%
import sys
sys.path.append("..")

from imageops.image import Image
import matplotlib.pyplot as plt

# %%
image = Image()
image.read("test_image_blog.png")

# %%
plt.imshow(image.data[:,:,0], cmap="gray", vmin=0, vmax=255)
plt.title("Red Channel")
plt.show()

plt.imshow(image.to_grayscale(), cmap="gray", vmin=0, vmax=255)
plt.title("Grayscale")
plt.show()
